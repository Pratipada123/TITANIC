# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Titanic_df=pd.read_csv(r"C:\Users\prati\OneDrive\Datafiles\Titanic-Dataset.csv")
Titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
cat=Titanic_df.select_dtypes(include='object').columns
num=Titanic_df.select_dtypes(exclude='object').columns
cat,num
# Out:
# (Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object'),
#  Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object'))

# %%
Titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
## drop the column 
Titanic_data=Titanic_df.drop(labels=['PassengerId'],axis=1)
Titanic_data
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
cat=Titanic_data.select_dtypes(include='object').columns
num=Titanic_data.select_dtypes(exclude='object').columns
cat,num
# Out:
# (Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object'),
#  Index(['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object'))

# %%
Titanic_data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')
for i in cat:
    Mode=Titanic_data[i].mode()
    Titanic_data[i].fillna(Mode.values[0],inplace=True)
Titanic_data
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare    Cabin Embarked
# ...

# %%
Titanic_data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin         0
# Embarked      0
# dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')
for i in num:
    Median=Titanic_data[i].median()
    Titanic_data[i].fillna(Median,inplace=True)
Titanic_data
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare    Cabin Embarked
# ...

# %%
Titanic_data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
## 1.Generate summary statistics (mean, median, std, etc.).

#calculate mean
mean_summary = Titanic_data.mean(numeric_only=True)
print("The Value of mean is:", mean_summary)

# calculate median
median_summary =Titanic_data.median(numeric_only=True)
print("The Value of median is:", median_summary)

# calculate standard deviation
std_summary =Titanic_data.std(numeric_only=True)
print("The Value of standard deviation is:", std_summary)

# calculate minimun 
min_summary =Titanic_data.min(numeric_only=True)
print("The Value of minimum is:", min_summary)

# calculate maximum
max_summary =Titanic_data.max(numeric_only=True)
print("The Value of maximum is:", max_summary)
# Out:
# The Value of mean is: Survived     0.383838
# Pclass       2.308642
# Age         29.361582
# SibSp        0.523008
# Parch        0.381594
# Fare        32.204208
# dtype: float64
# The Value of median is: Survived     0.0000
# Pclass       3.0000
# Age         28.0000
# SibSp        0.0000
# Parch        0.0000
# Fare        14.4542
# dtype: float64
# The Value of standard deviation is: Survived     0.486592
# Pclass       0.836071
# Age         13.019697
# SibSp        1.102743
# Parch        0.806057
# Fare        49.693429
# dtype: float64
# The Value of minimum is: Survived    0.00
# Pclass      1.00
# Age         0.42
# SibSp       0.00
# Parch       0.00
# Fare        0.00
# dtype: float64
# The Value of maximum is: Survived      1.0000
# Pclass        3.0000
# Age          80.0000
# SibSp         8.0000
# Parch         6.0000
# Fare        512.3292
# dtype: float64

# %%
Titanic_data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.361582    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.019697    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
## 2.Create histograms and boxplots for numeric features.

# Box Plot:

for i in num:
    plt.boxplot(Titanic_data[i])
    plt.title(f'{i}_boxplot')
    plt.show()

# %%
for i in num:
    plt.hist(Titanic_data[i])
    plt.title(f'{i}_boxplot')
    plt.show()

# %%
## 3.Use pairplot/correlation matrix for feature relationships.

correlation=Titanic_data.corr(numeric_only=True)
correlation
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481 -0.064910 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000 -0.339898  0.083081  0.018443 -0.549500
# Age      -0.064910 -0.339898  1.000000 -0.233296 -0.172482  0.096688
# SibSp    -0.035322  0.083081 -0.233296  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443 -0.172482  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500  0.096688  0.159651  0.216225  1.000000

# %%
numeric_cols = ['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# Create pairplot
sns.pairplot(Titanic_data[numeric_cols])
plt.suptitle("Pairplot of Titanic Numeric Features", y=1)
plt.show()

# %%
## 4.Identify patterns, trends, or anomalies in the data

########## Patterns & Trends ##########

print("\n--- Survival Rate by Gender ---")
survival_by_gender = Titanic_data.groupby('Sex')['Survived'].mean()
print(survival_by_gender)

print("\n--- Survival Rate by Passenger Class ---")
survival_by_class = Titanic_data.groupby('Pclass')['Survived'].mean()
print(survival_by_class)

print("\n--- Survival Rate by Embarked Port ---")
survival_by_embarked = Titanic_data.groupby('Embarked')['Survived'].mean()
print(survival_by_embarked)

# Plot survival by gender
sns.countplot(data=Titanic_data, x='Sex', hue='Survived')
plt.title("Survival Count by Gender")
plt.show()

# Plot survival by class
sns.countplot(data=Titanic_data, x='Pclass', hue='Survived')
plt.title("Survival Count by Passenger Class")
plt.show()

# Plot age distribution by survival
sns.histplot(data=Titanic_data, x='Age', hue='Survived', bins=30, kde=True)
plt.title("Age Distribution by Survival")
plt.show()

######## Anomalies #########

print("\n--- Missing Values ---")
missing_values = Titanic_data.isnull().sum()
print(missing_values)

# Boxplot to detect fare outliers
plt.figure(figsize=(8, 4))
sns.boxplot(x=Titanic_data['Fare'])
plt.title("Fare Outliers")
plt.show()

# Show most common duplicate tickets
print("\n--- Most Common Shared Tickets ---")
ticket_counts = Titanic_data['Ticket'].value_counts()
shared_tickets = ticket_counts[ticket_counts > 1]
print(shared_tickets.head())

########### Correlation Matrix (Numeric Pattern) ############

numeric_cols =['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']
correlation_matrix = Titanic_data[numeric_cols].corr()

print("\n--- Correlation Matrix ---")
print(correlation_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix of Numeric Features")
plt.show()
# Out:
# --- Survival Rate by Gender ---
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64
#
# --- Survival Rate by Passenger Class ---
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64
#
# --- Survival Rate by Embarked Port ---
# Embarked
# C    0.553571
# Q    0.389610
# S    0.339009
# Name: Survived, dtype: float64
# --- Missing Values ---
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64
# --- Most Common Shared Tickets ---
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
# Name: count, dtype: int64
#
# --- Correlation Matrix ---
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481 -0.064910 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000 -0.339898  0.083081  0.018443 -0.549500
# ...

# %%
## 5.Make basic feature-level inferences from visuals.


# Set plot style
sns.set(style="whitegrid")

## Survival by Gender ##
print("\n📌 Inference: Females had a much higher survival rate than males.\n")
sns.countplot(data=Titanic_data, x='Sex', hue='Survived')
plt.title("Survival by Gender")
plt.show()

## Survival by Passenger Class ##
print("\n📌 Inference: 1st class passengers were more likely to survive than 2nd and 3rd class passengers.\n")
sns.countplot(data=Titanic_data, x='Pclass', hue='Survived')
plt.title("Survival by Passenger Class")
plt.show()

## Age Distribution by Survival ##
print("\n📌 Inference: Children had better survival chances. Elderly had lower survival rates.\n")
sns.histplot(data=Titanic_data, x='Age', hue='Survived', bins=30, kde=True)
plt.title("Age Distribution by Survival")
plt.show()

## Fare Distribution (Boxplot) ##
print("\n📌 Inference: A few passengers paid very high fares (outliers), likely wealthy 1st class passengers.\n")
sns.boxplot(x=Titanic_data['Fare'])
plt.title("Fare Distribution with Outliers")
plt.show()

## Correlation Matrix ##
print("\n📌 Inference: Fare is negatively correlated with Pclass. SibSp and Parch are positively correlated.\n")
numeric_features = ['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']
corr_matrix = Titanic_data[numeric_features].corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix of Numeric Features")
plt.show()
# Out:
# 📌 Inference: Females had a much higher survival rate than males.
# 📌 Inference: 1st class passengers were more likely to survive than 2nd and 3rd class passengers.
# 📌 Inference: Children had better survival chances. Elderly had lower survival rates.
# 📌 Inference: A few passengers paid very high fares (outliers), likely wealthy 1st class passengers.
# 📌 Inference: Fare is negatively correlated with Pclass. SibSp and Parch are positively correlated.
